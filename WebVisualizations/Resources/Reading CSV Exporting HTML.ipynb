# %%
# Dependencies
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Store filepath in a variable
file_path = "CitiesWeather.csv"

# %%
# Read  Data file with the pandas library
citiesweatherDF = pd.read_csv(file_path, encoding="ISO-8859-1")
citiesweatherDF
# Out:
#             City Country  Latitude  Longitude                 Date  \
# 0           kang      BW  -23.6752    22.7876  2021-01-14 16:29:01
# 1     casablanca      MA   33.5928    -7.6192  2021-01-14 16:27:33
# 2        huarmey      PE  -10.0681   -78.1522  2021-01-14 16:29:00
# 3       khatanga      RU   71.9667   102.5000  2021-01-14 16:29:03
# 4      busselton      AU  -33.6500   115.3333  2021-01-14 16:29:04
# ..           ...     ...       ...        ...                  ...
# 577    chunhuhub      MX   19.5500   -88.6833  2021-01-14 16:35:40
# 578      jackson      US   42.4165  -122.8345  2021-01-14 16:35:41
# 579      tunceli      TR   39.1083    39.5471  2021-01-14 16:35:41
# 580  kangaatsiaq      GL   68.3065   -53.4641  2021-01-14 16:35:42
# 581         olga      RU   43.7444   135.2892  2021-01-14 16:35:43
#
#      Temperature  Humidity  Cloudiness  Wind Speed
# 0          30.77      33.0        69.0        2.41
# 1          14.51      55.0        40.0        2.06
# ...

# %%
citiesweatherDF.to_html("../assets/citiesweather.html", justify='left')

# %%
#Temperature plot
xlat = np.arange(-80, 100+1, 20)
plt.scatter(citiesweatherDF["Latitude"], citiesweatherDF["Temperature"], s=50, alpha=0.65)
plt.xticks(xlat)

#Set background colour
ax = plt.gca()
ax.set_facecolor('#e4e4e4')

#Set grid lines behind plots
ax.set_axisbelow(True)

#Remove border
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)


#set grid colour
plt.grid(color='white', linestyle='--', linewidth=0.75)

plt.title("City Latitude vs. Max Temperature (14/01/2021)")
plt.xlabel('Latitude')  
plt.ylabel('Max Temperature (c)')
plt.savefig('../assets/Lat_vs_Temp.png')

# %%
#Cloud plot
plt.scatter(citiesweatherDF["Latitude"], citiesweatherDF["Cloudiness"], s=50, alpha=0.65)
plt.xticks(xlat)

#Set background colour
ax = plt.gca()
ax.set_facecolor('#e4e4e4')

#Set grid lines behind plots
ax.set_axisbelow(True)

#Remove border
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

#set grid colour
plt.grid(color='white', linestyle='--', linewidth=0.75)
plt.title("City Latitude vs. Cloudiness (14/01/2021)")
plt.xlabel('Latitude')  
plt.ylabel('Cloudiness')
plt.savefig('../assets/Lat_vs_Cloud.png')

# %%
#Humid plot
plt.scatter(citiesweatherDF["Latitude"], citiesweatherDF["Humidity"], s=50, alpha=0.65)
plt.xticks(xlat)

#Set background colour
ax = plt.gca()
ax.set_facecolor('#e4e4e4')

#Set grid lines behind plots
ax.set_axisbelow(True)

#Remove border
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

#set grid colour
plt.grid(color='white', linestyle='--', linewidth=0.75)
plt.title("City Latitude vs. Humidity (14/01/2021)")
plt.xlabel('Latitude')  
plt.ylabel('Humidity')
plt.savefig('../assets/Lat_vs_Humid.png')

# %%
#Wind plot
plt.scatter(citiesweatherDF["Latitude"], citiesweatherDF["Wind Speed"], s=50, alpha=0.65)
plt.xticks(xlat)

#Set background colour
ax = plt.gca()
ax.set_facecolor('#e4e4e4')

#Set grid lines behind plots
ax.set_axisbelow(True)

#Remove border
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

#set grid colour
plt.grid(color='white', linestyle='--', linewidth=0.75)
plt.title("City Latitude vs. Wind Speed (14/01/2021)")
plt.xlabel('Latitude')  
plt.ylabel('Wind Speed')
plt.savefig('../assets/Lat_vs_Wind.png')
